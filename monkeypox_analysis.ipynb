# %%
import pandas as pd
import numpy as np
import scipy as sp
import statsmodels as sm

# %%
dataset = pd.read_csv('/Users/ikubannipaul/Downloads/datas/monkeypox.csv')

# %%
dataset.head()
# Out:
#   location        date iso_code  total_cases  total_deaths  new_cases  \
# 0   Africa  2022-05-01      NaN         42.0           2.0        2.0
# 1   Africa  2022-05-02      NaN         42.0           2.0        0.0
# 2   Africa  2022-05-03      NaN         42.0           2.0        0.0
# 3   Africa  2022-05-04      NaN         42.0           2.0        0.0
# 4   Africa  2022-05-05      NaN         42.0           2.0        0.0
#
#    new_deaths  new_cases_smoothed  new_deaths_smoothed  new_cases_per_million  \
# 0         0.0                0.29                  0.0                  0.001
# 1         0.0                0.29                  0.0                  0.000
# 2         0.0                0.29                  0.0                  0.000
# 3         0.0                0.29                  0.0                  0.000
# 4         0.0                0.29                  0.0                  0.000
#
#    total_cases_per_million  new_cases_smoothed_per_million  \
# ...

# %%
# dataset.loc[dataset['location'] == 'Africa', 'iso_code'] = 'AFR'
# dataset.head()

dataset['iso_code'] = dataset['iso_code'].fillna(dataset['location'].str[:3].str.upper())
dataset.head()
# Out:
#   location        date iso_code  total_cases  total_deaths  new_cases  \
# 0   Africa  2022-05-01      AFR         42.0           2.0        2.0
# 1   Africa  2022-05-02      AFR         42.0           2.0        0.0
# 2   Africa  2022-05-03      AFR         42.0           2.0        0.0
# 3   Africa  2022-05-04      AFR         42.0           2.0        0.0
# 4   Africa  2022-05-05      AFR         42.0           2.0        0.0
#
#    new_deaths  new_cases_smoothed  new_deaths_smoothed  new_cases_per_million  \
# 0         0.0                0.29                  0.0                  0.001
# 1         0.0                0.29                  0.0                  0.000
# 2         0.0                0.29                  0.0                  0.000
# 3         0.0                0.29                  0.0                  0.000
# 4         0.0                0.29                  0.0                  0.000
#
#    total_cases_per_million  new_cases_smoothed_per_million  \
# ...

# %%
dataset['location'].value_counts()
# Out:
# location
# Central African Republic    823
# Africa                      820
# Nigeria                     820
# Ghana                       820
# World                       820
#                            ...
# Laos                          1
# Kenya                         1
# Iran                          1
# Guam                          1
# Jordan                        1
# Name: count, Length: 127, dtype: int64

# %%
dataset['total_cases'].isnull().sum()
# Out:
# 12

# %%
dataset[dataset['new_cases'].isnull()]
# Out:
#                            location        date iso_code  total_cases  \
# 12077                       Burundi  2024-08-03      NaN          NaN
# 12078                       Burundi  2024-08-09      NaN          NaN
# 12079                       Burundi  2024-08-16      NaN          NaN
# 12966                      Cameroon  2024-07-28      NaN          NaN
# 14581      Central African Republic  2024-08-03      NaN          NaN
# 14582      Central African Republic  2024-08-10      NaN          NaN
# 14583      Central African Republic  2024-08-16      NaN          NaN
# 17637                         Congo  2024-08-11      NaN          NaN
# 22668  Democratic Republic of Congo  2024-07-28      NaN          NaN
# 22669  Democratic Republic of Congo  2024-08-03      NaN          NaN
# 22670  Democratic Republic of Congo  2024-08-12      NaN          NaN
# 22671  Democratic Republic of Congo  2024-08-16      NaN          NaN
#
# ...
